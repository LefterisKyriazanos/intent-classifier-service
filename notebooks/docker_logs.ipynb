# %% [markdown]
# ### `./run_container.sh` command
#
# -  Builds and runs the app

# %% [markdown]
# ### run server with Docker (zero-shot) on the whole Test set (850)
#
#
# ```
# ./run_container.sh
# [+] Building 127.1s (14/14) FINISHED
#  => [internal] load build definition from Dockerfile                                                                                                                                                   0.1s
#  => => transferring dockerfile: 37B                                                                                                                                                                    0.0s
#  => [internal] load .dockerignore                                                                                                                                                                      0.0s
#  => => transferring context: 35B                                                                                                                                                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim                                                                                                                                    2.3s
#  => [1/9] FROM docker.io/library/python:3.11-slim@sha256:fc39d2e68b554c3f0a5cb8a776280c0b3d73b4c04b83dbade835e2a171ca27ef                                                                              0.0s
#  => [internal] load build context                                                                                                                                                                      0.0s
#  => => transferring context: 67.94kB                                                                                                                                                                   0.0s
#  => CACHED [2/9] WORKDIR /app                                                                                                                                                                          0.0s
#  => [3/9] COPY requirements.txt requirements.txt                                                                                                                                                       0.0s
#  => [4/9] RUN pip3 install --no-cache-dir -r requirements.txt                                                                                                                                        109.9s
#  => [5/9] COPY . .                                                                                                                                                                                     0.1s
#  => [6/9] RUN mkdir -p model_evaluation                                                                                                                                                                0.5s
#  => [7/9] RUN [ "python3", "-c", "import nltk; nltk.download('punkt', download_dir='/usr/local/nltk_data')" ]                                                                                          4.5s
#  => [8/9] COPY entrypoint.sh /entrypoint.sh                                                                                                                                                            0.0s
#  => [9/9] RUN chmod +x /entrypoint.sh                                                                                                                                                                  0.4s
#  => exporting to image                                                                                                                                                                                 9.1s
#  => => exporting layers                                                                                                                                                                                9.1s
#  => => writing image sha256:1e9d79aafa07f18c69652c8f1c1950e1e638d84c0b617d25b51d294f713cc5d3                                                                                                           0.0s
#  => => naming to docker.io/library/intent-classifier-app                                                                                                                                               0.0s
#
# Use 'docker scan' to run Snyk tests against images to find vulnerabilities and learn how to fix them
# [nltk_data] Downloading package stopwords to /usr/local/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /usr/local/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
#
# class (classifier):  GPT
# model_name:  gpt-3.5-turbo
# model_classifier_type:  zero-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
#
#
# model_unknown_targets:  {'day_name'}
#
# valid,  invalid
# 848 0
# ['flight'] ['flight', 'airport', 'city']
# ['airfare'] ['flight', 'city', 'flight_no']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'distance', 'flight_no']
# ['flight'] ['flight', 'city', 'flight_no']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'flight_no', 'airport']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'city', 'meal']
# ... more responses
#
# ['flight'] ['flight', 'city', 'airport']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'city', 'airport']
# ['airline'] ['airline', 'flight', 'airport']
# ['flight'] ['flight', 'flight_time', 'airport']
# ['flight'] ['flight', 'city', 'flight_no']
# ['flight'] ['flight', 'city', 'flight_no']
# ['airport'] ['airport', 'city', 'flight']
# ['flight'] ['flight', 'airline', 'city']
# ['airport'] ['airport', 'city', 'airfare']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'city', 'airline']
# ['flight'] ['flight', 'city', 'restriction']
# ['flight'] ['flight', 'city', 'flight_no']
#
# Class 'abbreviation':
#   Precision: 0.7666666666666667
#   Recall: 0.8846153846153846
#   F1 Score: 0.8214285714285714
#   Confusion Matrix:
# [[815   7]
#  [  3  23]]
#
# Class 'aircraft':
#   Precision: 0.19047619047619047
#   Recall: 1.0
#   F1 Score: 0.32
#   Confusion Matrix:
# [[806  34]
#  [  0   8]]
#
# Class 'airfare':
#   Precision: 0.6511627906976745
#   Recall: 0.9180327868852459
#   F1 Score: 0.7619047619047619
#   Confusion Matrix:
# [[757  30]
#  [  5  56]]
#
# Class 'airline':
#   Precision: 0.2097902097902098
#   Recall: 1.0
#   F1 Score: 0.3468208092485549
#   Confusion Matrix:
# [[705 113]
#  [  0  30]]
#
# Class 'airport':
#   Precision: 0.029953917050691243
#   Recall: 1.0
#   F1 Score: 0.058165548098434
#   Confusion Matrix:
# [[414 421]
#  [  0  13]]
#
# Class 'capacity':
#   Precision: 0.8
#   Recall: 0.9523809523809523
#   F1 Score: 0.8695652173913043
#   Confusion Matrix:
# [[822   5]
#  [  1  20]]
#
# Class 'cheapest':
#   Precision: 0.0
#   Recall: 0.0
#   F1 Score: 0.0
#   Confusion Matrix:
# [[802  46]
#  [  0   0]]
#
# Class 'city':
#   Precision: 0.008547008547008548
#   Recall: 1.0
#   F1 Score: 0.01694915254237288
#   Confusion Matrix:
# [[263 580]
#  [  0   5]]
#
# Class 'distance':
#   Precision: 0.15
#   Recall: 0.9
#   F1 Score: 0.2571428571428571
#   Confusion Matrix:
# [[787  51]
#  [  1   9]]
#
# Class 'flight':
#   Precision: 0.9024390243902439
#   Recall: 0.9441786283891547
#   F1 Score: 0.9228371005455963
#   Confusion Matrix:
# [[157  64]
#  [ 35 592]]
#
# Class 'flight_no':
#   Precision: 0.04090909090909091
#   Recall: 1.0
#   F1 Score: 0.07860262008733625
#   Confusion Matrix:
# [[628 211]
#  [  0   9]]
#
# Class 'flight_time':
#   Precision: 0.011904761904761904
#   Recall: 1.0
#   F1 Score: 0.023529411764705882
#   Confusion Matrix:
# [[764  83]
#  [  0   1]]
#
# Class 'ground_fare':
#   Precision: 0.2
#   Recall: 0.5714285714285714
#   F1 Score: 0.2962962962962963
#   Confusion Matrix:
# [[825  16]
#  [  3   4]]
#
# Class 'ground_service':
#   Precision: 0.6923076923076923
#   Recall: 1.0
#   F1 Score: 0.8181818181818182
#   Confusion Matrix:
# [[796  16]
#  [  0  36]]
#
# Class 'meal':
#   Precision: 0.24
#   Recall: 1.0
#   F1 Score: 0.3870967741935484
#   Confusion Matrix:
# [[823  19]
#  [  0   6]]
#
# Class 'quantity':
#   Precision: 0.0
#   Recall: 0.0
#   F1 Score: 0.0
#   Confusion Matrix:
# [[823  22]
#  [  3   0]]
#
# Class 'restriction':
#   Precision: 0.0
#   Recall: 0.0
#   F1 Score: 0.0
#   Confusion Matrix:
# [[837  11]
#  [  0   0]]
#
# Average Metrics:
# Overall Confusion Matrix:
# [[11824  1729]
#  [   51   812]]
#   Accuracy: 0.9398584905660378
#   (macro) Precision: 0.28789160898471944
#   (micro) Precision: 0.31955922865013775
#   (weighted) Precision: 0.7881533570610054
#   (macro) Recall: 0.7747433131587829
#   (micro) Recall: 0.9409038238702202
# INFO:     Started server process [7]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8080 (Press CTRL+C to quit)
#
#
# ```

# %% [markdown]
# ```
# => => transferring context: 75.03kB                                                                                                                                                                   0.0s
#  => CACHED [2/9] WORKDIR /app                                                                                                                                                                          0.0s
#  => CACHED [3/9] COPY requirements.txt requirements.txt                                                                                                                                                0.0s
#  => CACHED [4/9] RUN pip3 install --no-cache-dir -r requirements.txt                                                                                                                                   0.0s
#  => [5/9] COPY . .                                                                                                                                                                                     0.0s
#  => [6/9] RUN mkdir -p model_evaluation                                                                                                                                                                0.5s
#  => [7/9] RUN [ "python3", "-c", "import nltk; nltk.download('punkt', download_dir='/usr/local/nltk_data')" ]                                                                                          5.8s
#  => [8/9] COPY entrypoint.sh /entrypoint.sh                                                                                                                                                            0.1s
#  => [9/9] RUN chmod +x /entrypoint.sh                                                                                                                                                                  0.9s
#  => exporting to image                                                                                                                                                                                 1.3s
#  => => exporting layers                                                                                                                                                                                1.2s
#  => => writing image sha256:e21a4695f12fef874157efec0afc9bf555979faf4a8b4889a6c3e5c655d5f010                                                                                                           0.0s
#  => => naming to docker.io/library/intent-classifier-app                                                                                                                                               0.0s
#
# Use 'docker scan' to run Snyk tests against images to find vulnerabilities and learn how to fix them
# [nltk_data] Downloading package stopwords to /usr/local/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /usr/local/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
#
#
# class (classifier):  GPT
# model_name:  gpt-3.5-turbo
# model_classifier_type:  few-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
#
#
# model_unknown_targets:  {'day_name'}
# bad response:  [text: [0, 5, 12]]
#
# valid,  invalid
# 847 1
# ['flight'] ['flight', 'airport', 'aircraft']
# ['airfare'] ['flight', 'city', 'ground_service']
# ['flight'] ['flight', 'restriction', 'distance']
# ['flight'] ['flight', 'abbreviation', 'flight_no']
# ['flight'] ['flight', 'airline', 'city']
# ['flight'] ['flight', 'flight_no', 'restriction']
# ['flight'] ['flight', 'city', 'flight_time']
# ['flight'] ['flight', 'flight_time', 'city']
# ['flight'] ['flight', 'flight_time', 'airline']
# ['flight'] ['flight', 'city', 'flight_time']
# ['flight'] ['flight', 'flight_time', 'meal']
# ['flight'] ['flight', 'airport', 'meal']
#
#
#
#
# ... more responses
# ['ground_service'] ['ground_service', 'city', 'cheapest']
# ['ground_fare'] ['airfare', 'ground_fare', 'restriction']
# ['ground_fare'] ['airfare', 'ground_service', 'airport']
# ['flight'] ['flight', 'airport', 'quantity']
# ['ground_service'] ['ground_service', 'airport', 'city']
# ['flight'] ['flight', 'flight_no', 'airline']
# ['flight'] ['flight', 'airline', 'city']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airport', 'city']
#
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airline', 'city']
# ['flight'] ['flight', 'airfare', 'city']
# ['flight'] ['flight', 'airport', 'city']
#
# Class 'abbreviation':
#   Precision: 0.5365853658536586
#   Recall: 0.8461538461538461
#   F1 Score: 0.6567164179104478
#   Confusion Matrix:
# [[802  19]
#  [  4  22]]
#
# Class 'aircraft':
#   Precision: 0.20512820512820512
#   Recall: 1.0
#   F1 Score: 0.3404255319148936
#   Confusion Matrix:
# [[808  31]
#  [  0   8]]
#
# Class 'airfare':
#   Precision: 0.5086206896551724
#   Recall: 0.9672131147540983
#   F1 Score: 0.6666666666666666
#   Confusion Matrix:
# [[729  57]
#  [  2  59]]
#
# Class 'airline':
#   Precision: 0.1986754966887417
#   Recall: 1.0
#   F1 Score: 0.3314917127071823
#   Confusion Matrix:
# [[696 121]
#  [  0  30]]
#
# Class 'airport':
#   Precision: 0.03117505995203837
#   Recall: 1.0
#   F1 Score: 0.06046511627906977
#   Confusion Matrix:
# [[430 404]
#  [  0  13]]
#
# Class 'capacity':
#   Precision: 0.65625
#   Recall: 1.0
#   F1 Score: 0.7924528301886793
#   Confusion Matrix:
# [[815  11]
#  [  0  21]]
#
# Class 'cheapest':
#   Precision: 0.0
#   Recall: 0.0
#   F1 Score: 0.0
#   Confusion Matrix:
# [[742 105]
#  [  0   0]]
#
# Class 'city':
# INFO:     Started server process [8]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8080 (Press CTRL+C to quit)
#   Precision: 0.016611295681063124
#   Recall: 1.0
#   F1 Score: 0.032679738562091505
#   Confusion Matrix:
# [[546 296]
#  [  0   5]]
#
# Class 'distance':
#   Precision: 0.14705882352941177
#   Recall: 1.0
#   F1 Score: 0.2564102564102564
#   Confusion Matrix:
# [[779  58]
#  [  0  10]]
#
# Class 'flight':
#   Precision: 0.8893740902474527
#   Recall: 0.9760383386581469
#   F1 Score: 0.9306930693069307
#   Confusion Matrix:
# [[145  76]
#  [ 15 611]]
#
# Class 'flight_no':
#   Precision: 0.0743801652892562
#   Recall: 1.0
#   F1 Score: 0.13846153846153847
#   Confusion Matrix:
# [[726 112]
#  [  0   9]]
#
# Class 'flight_time':
#   Precision: 0.005
#   Recall: 1.0
#   F1 Score: 0.009950248756218905
#   Confusion Matrix:
# [[647 199]
#  [  0   1]]
#
# Class 'ground_fare':
#   Precision: 0.2857142857142857
#   Recall: 0.8571428571428571
#   F1 Score: 0.42857142857142855
#   Confusion Matrix:
# [[825  15]
#  [  1   6]]
#
# Class 'ground_service':
#   Precision: 0.6206896551724138
#   Recall: 1.0
#   F1 Score: 0.7659574468085106
#   Confusion Matrix:
# [[789  22]
#  [  0  36]]
#
# Class 'meal':
#   Precision: 0.2
#   Recall: 1.0
#   F1 Score: 0.3333333333333333
#   Confusion Matrix:
# [[817  24]
#  [  0   6]]
#
# Class 'quantity':
#   Precision: 0.022727272727272728
#   Recall: 0.3333333333333333
#   F1 Score: 0.0425531914893617
#   Confusion Matrix:
# [[801  43]
#  [  2   1]]
#
# Class 'restriction':
#   Precision: 0.0
#   Recall: 0.0
#   F1 Score: 0.0
#   Confusion Matrix:
# [[750  97]
#  [  0   0]]
#
# Average Metrics:
# Overall Confusion Matrix:
# [[11847  1690]
#  [   24   838]]
#   Accuracy: 0.9716646989374262
#   (macro) Precision: 0.25870531797876306
#   (micro) Precision: 0.3314873417721519
#   (weighted) Precision: 0.755631269144805
#   (macro) Recall: 0.8223459700024871
#   (micro) Recall: 0.9721577726218097
#   (weighted) Recall: 0.9721577726218097
#   (macro) F1 Score: 0.3404016780803888
#   (micro) F1 Score: 0.4943952802359882
#   (weighted) F1 Score: 0.8203440829605559
#
# Model loaded successfully!
#
#
# Starting Server..
#
# INFO:     172.17.0.1:61044 - "POST /intent HTTP/1.1" 200 OK
# INFO:     172.17.0.1:61050 - "POST /intent HTTP/1.1" 200 OK
# INFO:     172.17.0.1:61054 - "POST /intent HTTP/1.1" 200 OK
# INFO:     172.17.0.1:61058 - "POST /intent HTTP/1.1" 200 OK
# INFO:     172.17.0.1:61062 - "POST /intent HTTP/1.1" 200 OK
# INFO:     172.17.0.1:61066 - "POST /intent HTTP/1.1" 200 OK
# INFO:     172.17.0.1:61070 - "POST /intent HTTP/1.1" 200 OK
# INFO:     172.17.0.1:61074 - "POST /intent HTTP/1.1" 200 OK
#
#
#
# ```
