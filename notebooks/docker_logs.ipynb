# %% [markdown]
# ### `./run_container.sh` command
#
# -  Builds and runs the app

# %% [markdown]
# ```
# ./run_container.sh
#
# [+] Building 5.5s (14/14) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 35B                                           0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.7s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 63.99kB                                       0.0s
#  => [1/9] FROM docker.io/library/python:3.11-slim@sha256:fc39d2e68b554c3f  0.0s
#  => CACHED [2/9] WORKDIR /app                                              0.0s
#  => CACHED [3/9] COPY requirements.txt requirements.txt                    0.0s
#  => CACHED [4/9] RUN pip3 install --no-cache-dir -r requirements.txt       0.0s
#  => [5/9] COPY . .                                                         0.0s
#  => [6/9] RUN mkdir -p model_evaluation                                    0.4s
#  => [7/9] RUN [ "python3", "-c", "import nltk; nltk.download('punkt', dow  3.1s
#  => [8/9] COPY entrypoint.sh /entrypoint.sh                                0.0s
#  => [9/9] RUN chmod +x /entrypoint.sh                                      0.4s
#  => exporting to image                                                     0.4s
#  => => exporting layers                                                    0.4s
#  => => writing image sha256:e5ddaa4ddd54718ceb1dad47449677c04a33005b1bf2a  0.0s
#  => => naming to docker.io/library/intent-classifier-app                   0.0s
#
# Use 'docker scan' to run Snyk tests against images to find vulnerabilities and learn how to fix them
# [nltk_data] Downloading package stopwords to /usr/local/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /usr/local/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# INFO:     Started server process [8]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8080 (Press CTRL+C to quit)
#
# class (classifier):  GPT
# model_name:  gpt-3.5-turbo
# model_classifier_type:  zero-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
#
#
# model_unknown_targets:  {'day_name'}
#
# test size:  30
# unique eval classes:  19
# eval samples per class:  1
# any remaining test records will be sampled randomly
#
# valid,  invalid
# 30 0
# ['flight'] ['airport', 'city', 'flight']
# ['airfare'] ['flight', 'airport', 'city']
# ['flight', 'airfare'] ['airfare', 'flight', 'ground_service']
# ['ground_service'] ['ground_service', 'airport', 'flight']
# ['meal'] ['meal', 'airline', 'flight_no']
# ['airport'] ['airport', 'city', 'flight_time']
# ['airline'] ['airline', 'flight', 'flight_no']
# ['flight_time'] ['flight', 'city', 'flight_no']
# ['city'] ['city', 'flight', 'distance']
# ['ground_fare'] ['ground_fare', 'airport', 'airline']
# ['quantity'] ['airline', 'flight', 'aircraft']
# ['abbreviation'] ['abbreviation', 'quantity', 'flight']
# ['distance'] ['distance', 'airport', 'city']
# ['aircraft'] ['aircraft', 'flight', 'airline']
# ['airfare', 'flight'] ['flight', 'airfare', 'airline']
# ['capacity'] ['capacity', 'abbreviation', 'quantity']
# ['flight', 'airline'] ['flight', 'airline', 'city']
# ['flight_no', 'airline'] ['flight', 'airline', 'flight_no']
# ['flight_no'] ['airport', 'flight', 'flight_no']
# ['flight'] ['flight', 'city', 'airport']
# ['flight'] ['flight', 'city', 'aircraft']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'flight_no', 'airfare']
# ['flight'] ['flight', 'flight_time', 'flight_no']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'city', 'airport']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'distance', 'city']
# ['flight'] ['flight', 'cheapest', 'flight_no']
#
# :      accuracy
# 0  0.911765
#
# :               intent  precision
# 0           flight   0.600000
# 1      flight_time   0.000000
# 2          airfare   0.666667
# 3         aircraft   0.333333
# 4   ground_service   0.500000
# 5          airport   0.076923
# 6          airline   0.375000
# 7         distance   0.333333
# 8     abbreviation   0.500000
# 9      ground_fare   1.000000
# 10        quantity   0.000000
# 11            city   0.066667
# 12       flight_no   0.250000
# 13        capacity   1.000000
# 14            meal   1.000000
# 15     restriction   0.000000
# 16        cheapest   0.000000
#
# :               intent    recall
# 0           flight  1.000000
# 1      flight_time  0.000000
# 2          airfare  0.666667
# 3         aircraft  1.000000
# 4   ground_service  1.000000
# 5          airport  1.000000
# 6          airline  1.000000
# 7         distance  1.000000
# 8     abbreviation  1.000000
# 9      ground_fare  1.000000
# 10        quantity  0.000000
# 11            city  1.000000
# 12       flight_no  1.000000
# 13        capacity  1.000000
# 14            meal  1.000000
# 15     restriction  0.000000
# 16        cheapest  0.000000
#
# Model loaded successfully!
#
#
# Starting Server..
#
# INFO:     172.17.0.1:55686 - "POST /intent HTTP/1.1" 200 OK
# INFO:     172.17.0.1:55692 - "POST /intent HTTP/1.1" 400 Bad Request
# INFO:     172.17.0.1:55696 - "POST /intent HTTP/1.1" 200 OK
# INFO:     172.17.0.1:55702 - "POST /intent HTTP/1.1" 200 OK
# INFO:     172.17.0.1:55708 - "POST /intent HTTP/1.1" 200 OK
# INFO:     172.17.0.1:55712 - "POST /intent HTTP/1.1" 200 OK
#
#
#
# ```
