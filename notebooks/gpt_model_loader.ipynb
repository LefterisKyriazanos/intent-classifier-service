# %% [markdown]
# ## Load - GPT Classifier
#
# ### The load function is responsible for iniatializing the model before running the server.
#
# In more detail the model loader (load function) is responsible for:
#
# 1. preprocessesing of training and test datasets
# 2. choosing training data (examples) in case `few-shot` classifier is selected  (see [data_management](./data_management.ipynb)).
# 3. creating json like representations of classes (labeled intents)
# 4. choosing the most representative test_ds based on `test_size` (usually 40-50 records)  (see [data_management](./data_management.ipynb)).
# 5. creating evaluation metrics based on model performance on test data  (see [evaluation_metrics](./evaluation_metrics.ipynb))
# 6. deciding status ('SUCCESS', 'FAIL') based on evaluation thresholds.
#
#
# more at [gpt_intent_classifier](../gpt_intent_classifier.py) -  `load` method

# %% [markdown]
# ## LOAD LOGS FOR ZERO-SHOT CLASSIFIER
#
#
# (.venv) (base) lef@MacBook-Pro-Lefteris intent_classifier_service % /Users/lef/Desktop/intent_classifier_service/.venv/bin/python /Users/lef/
# Desktop/intent_classifier_service/gpt_intent_classifier.py
# ```
# in main
#
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/e.kyriazanos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/e.kyriazanos/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
# class (classifier):  GPT
# model_name:  gpt-3.5-turbo
# model_classifier_type:  zero-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
#
#
# model_unknown_targets:  {'day_name'}
#
#
# bad response:  The text you provided relates to the intents: flight, airfare, and cheapest.
# Therefore, the corresponding labels would be: [0, 2, 16]
# bad response:  The most likely class labels for the given text are: [2, 5, 16]
#  The text you provided relates to the intents: flight, airfare, and cheapest.
# Therefore, the corresponding labels would be: [0, 2, 16]
# valid,  invalid
# 846 2
# ['flight'] ['flight', 'city', 'flight_no']
# ['airfare'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'city', 'flight_no']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'city', 'flight_time']
# ['flight'] ['flight', 'flight_no', 'airport']
# ['flight'] ['flight', 'city', 'flight_no']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'city', 'meal']
# ['flight'] ['flight', 'city', 'airport']
# ['flight', 'airfare'] ['flight_time', 'airfare', 'cheapest']
# ['flight'] ['flight', 'city', 'airport']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'city', 'flight_no']
# ['flight'] ['flight', 'flight_no', 'city']
# ...
#
# ['flight'] ['flight', 'restriction', 'meal']
# ['flight'] ['flight', 'distance', 'city']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'city', 'airport']
# ['airline'] ['airport', 'airline', 'city']
# ['flight'] ['flight', 'flight_no', 'airport']
# ['flight'] ['flight', 'city', 'flight_no']
# ['flight'] ['flight', 'city', 'airport']
# ['airport'] ['airport', 'city', 'ground_service']
# ['flight'] ['flight', 'airport', 'airline']
# ['airport'] ['airport', 'city', 'ground_fare']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'city', 'airport']
# ['flight'] ['flight', 'city', 'airline']
# ['flight'] ['flight', 'city', 'airline']
# ['flight'] ['flight', 'airport', 'city']
#
# Class 'abbreviation':
#   Precision: 0.8333333333333334
#   Recall: 0.7692307692307693
#   F1 Score: 0.8
#   Confusion Matrix:
# [[816   4]
#  [  6  20]]
#
# Class 'aircraft':
#   Precision: 0.19047619047619047
#   Recall: 1.0
#   F1 Score: 0.32
#   Confusion Matrix:
# [[804  34]
#  [  0   8]]
#
# Class 'airfare':
#   Precision: 0.7105263157894737
#   Recall: 0.9
#   F1 Score: 0.7941176470588235
#   Confusion Matrix:
# [[764  22]
#  [  6  54]]
#
# Class 'airline':
#   Precision: 0.22058823529411764
#   Recall: 1.0
#   F1 Score: 0.3614457831325301
#   Confusion Matrix:
# [[710 106]
#  [  0  30]]
#
# Class 'airport':
#   Precision: 0.029748283752860413
#   Recall: 1.0
#   F1 Score: 0.057777777777777775
#   Confusion Matrix:
# [[409 424]
#  [  0  13]]
#
# Class 'capacity':
#   Precision: 0.7142857142857143
#   Recall: 0.9523809523809523
#   F1 Score: 0.8163265306122449
#   Confusion Matrix:
# [[817   8]
#  [  1  20]]
#
# Class 'cheapest':
#   Precision: 0.0
#   Recall: 0.0
#   F1 Score: 0.0
#   Confusion Matrix:
# [[797  49]
#  [  0   0]]
#
# Class 'city':
#   Precision: 0.008431703204047217
#   Recall: 1.0
#   F1 Score: 0.016722408026755852
#   Confusion Matrix:
# [[253 588]
#  [  0   5]]
#
# Class 'distance':
#   Precision: 0.1694915254237288
#   Recall: 1.0
#   F1 Score: 0.2898550724637681
#   Confusion Matrix:
# [[787  49]
#  [  0  10]]
#
# Class 'flight':
#   Precision: 0.8935532233883059
#   Recall: 0.9536
#   F1 Score: 0.9226006191950464
#   Confusion Matrix:
# [[150  71]
#  [ 29 596]]
#
# Class 'flight_no':
#   Precision: 0.038834951456310676
#   Recall: 0.8888888888888888
#   F1 Score: 0.07441860465116279
#   Confusion Matrix:
# [[639 198]
#  [  1   8]]
#
# Class 'flight_time':
#   Precision: 0.011627906976744186
#   Recall: 1.0
#   F1 Score: 0.022988505747126436
#   Confusion Matrix:
# [[760  85]
#  [  0   1]]
#
# Class 'ground_fare':
#   Precision: 0.2
#   Recall: 0.5714285714285714
#   F1 Score: 0.2962962962962963
#   Confusion Matrix:
# [[823  16]
#  [  3   4]]
#
# Class 'ground_service':
#   Precision: 0.6862745098039216
#   Recall: 0.9722222222222222
#   F1 Score: 0.8045977011494253
#   Confusion Matrix:
# [[794  16]
#  [  1  35]]
#
# Class 'meal':
#   Precision: 0.2608695652173913
#   Recall: 1.0
#   F1 Score: 0.41379310344827586
#   Confusion Matrix:
# [[823  17]
#  [  0   6]]
#
# Class 'quantity':
#   Precision: 0.0
#   Recall: 0.0
#   F1 Score: 0.0
#   Confusion Matrix:
# [[821  22]
#  [  3   0]]
#
# Class 'restriction':
#   Precision: 0.0
#   Recall: 0.0
#   F1 Score: 0.0
#   Confusion Matrix:
# [[832  14]
#  [  0   0]]
#
# Average Metrics:
# Overall Confusion Matrix:
# [[11799  1723]
#  [   50   810]]
#   Accuracy: 0.9408983451536643
#   (macro) Precision: 0.2922377328471847
#   (micro) Precision: 0.3197789182787209
#   (weighted) Precision: 0.7861238494043409
#   (macro) Recall: 0.7651618473030237
#   (micro) Recall: 0.9418604651162791
#   (weighted) Recall: 0.9418604651162791
#   (macro) F1 Score: 0.3524082382093667
#   (micro) F1 Score: 0.47745358090185674
#   (weighted) F1 Score: 0.8297291351359298
#
# Model loaded successfully!
#
#
# Starting Server..
#
# INFO:     Started server process [80044]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8080 (Press CTRL+C to quit)
#
#
# ```

# %% [markdown]
# ## LOAD LOGS FOR FEW-SHOT CLASSIFIER
# (.venv) (base) lef@MacBook-Pro-Lefteris intent_classifier_service % /Users/lef/Desktop/intent_classifier_service/.venv/bin/python /Users/lef/
# Desktop/intent_classifier_service/gpt_intent_classifier.py
# ```
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/e.kyriazanos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/e.kyriazanos/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#
# class (classifier):  GPT
# model_name:  gpt-3.5-turbo
# model_classifier_type:  few-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
#
#
# model_unknown_targets:  {'day_name'}
#
# valid,  invalid
# 848 0
# ['flight'] ['flight', 'flight_no', 'city']
# ['airfare'] ['flight', 'flight_time', 'flight_no']
# ['flight'] ['flight', 'airfare', 'cheapest']
# ['flight'] ['flight', 'flight_time', 'airfare']
# ['flight'] ['flight', 'distance', 'city']
# ['flight'] ['flight', 'airport', 'airline']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'flight_time', 'airfare']
#
# ....
# ['flight'] ['flight', 'airport', 'airline']
# ['flight'] ['flight', 'ground_service', 'cheapest']
# ['airport'] ['airport', 'city', 'ground_service']
# ['flight'] ['flight', 'airline', 'city']
#
#
# ['airport'] ['airport', 'distance', 'city']
# ['flight'] ['flight', 'airport', 'flight_time']
# ['flight'] ['flight', 'airport', 'city']
# ['flight'] ['flight', 'airline', 'airfare']
# ['flight'] ['flight', 'cheapest', 'flight_time']
# ['flight'] ['flight', 'city', 'aircraft']
#
# Class 'abbreviation':
#   Precision: 0.6
#   Recall: 0.8076923076923077
#   F1 Score: 0.6885245901639344
#   Confusion Matrix:
# [[808  14]
#  [  5  21]]
#
# Class 'aircraft':
#   Precision: 0.1568627450980392
#   Recall: 1.0
#   F1 Score: 0.2711864406779661
#   Confusion Matrix:
# [[797  43]
#  [  0   8]]
#
# Class 'airfare':
#   Precision: 0.48717948717948717
#   Recall: 0.9344262295081968
#   F1 Score: 0.6404494382022472
#   Confusion Matrix:
# [[727  60]
#  [  4  57]]
#
# Class 'airline':
#   Precision: 0.19852941176470587
#   Recall: 0.9
#   F1 Score: 0.3253012048192771
#   Confusion Matrix:
# [[709 109]
#  [  3  27]]
#
# Class 'airport':
#   Precision: 0.05263157894736842
#   Recall: 1.0
#   F1 Score: 0.1
#   Confusion Matrix:
# [[601 234]
#  [  0  13]]
#
# Class 'capacity':
#   Precision: 0.5384615384615384
#   Recall: 1.0
#   F1 Score: 0.7
#   Confusion Matrix:
# [[809  18]
#  [  0  21]]
#
# Class 'cheapest':
#   Precision: 0.0
#   Recall: 0.0
#   F1 Score: 0.0
#   Confusion Matrix:
# [[752  96]
#  [  0   0]]
#
# Class 'city':
#   Precision: 0.013157894736842105
#   Recall: 1.0
#   F1 Score: 0.025974025974025976
#   Confusion Matrix:
# [[468 375]
#  [  0   5]]
#
# Class 'distance':
#   Precision: 0.16666666666666666
#   Recall: 1.0
#   F1 Score: 0.2857142857142857
#   Confusion Matrix:
# [[788  50]
#  [  0  10]]
#
# Class 'flight':
#   Precision: 0.876770538243626
#   Recall: 0.9872408293460925
#   F1 Score: 0.9287321830457614
#   Confusion Matrix:
# [[134  87]
#  [  8 619]]
#
# Class 'flight_no':
#   Precision: 0.07207207207207207
#   Recall: 0.8888888888888888
#   F1 Score: 0.13333333333333333
#   Confusion Matrix:
# [[736 103]
#  [  1   8]]
#
# Class 'flight_time':
#   Precision: 0.0036231884057971015
#   Recall: 1.0
#   F1 Score: 0.007220216606498195
#   Confusion Matrix:
# [[572 275]
#  [  0   1]]
#
# Class 'ground_fare':
#   Precision: 0.25
#   Recall: 0.7142857142857143
#   F1 Score: 0.37037037037037035
#   Confusion Matrix:
# [[826  15]
#  [  2   5]]
#
# Class 'ground_service':
#   Precision: 0.5714285714285714
#   Recall: 1.0
#   F1 Score: 0.7272727272727273
#   Confusion Matrix:
# [[785  27]
#  [  0  36]]
#
# Class 'meal':
#   Precision: 0.2
#   Recall: 1.0
#   F1 Score: 0.3333333333333333
#   Confusion Matrix:
# [[818  24]
#  [  0   6]]
#
# Class 'quantity':
#   Precision: 0.0
#   Recall: 0.0
#   F1 Score: 0.0
#   Confusion Matrix:
# [[743 102]
#  [  3   0]]
#
# Class 'restriction':
#   Precision: 0.0
#   Recall: 0.0
#   F1 Score: 0.0
#   Confusion Matrix:
# [[807  41]
#  [  0   0]]
#
# Average Metrics:
# Overall Confusion Matrix:
# [[11880  1673]
#  [   26   837]]
#   Accuracy: 0.9693396226415094
#   (macro) Precision: 0.24631668782380675
#   (micro) Precision: 0.33346613545816733
#   (weighted) Precision: 0.7417866974429544
#   (macro) Recall: 0.7783843511600705
#   (micro) Recall: 0.9698725376593279
#   (weighted) Recall: 0.9698725376593279
#   (macro) F1 Score: 0.3257301264419859
#   (micro) F1 Score: 0.4962941002075304
#   (weighted) F1 Score: 0.8136515706747672
#
# Model loaded successfully!
#
#
# Starting Server..
#
# INFO:     Started server process [83647]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8080 (Press CTRL+C to quit)
#
#
# ```
