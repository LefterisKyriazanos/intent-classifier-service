# %% [markdown]
# ## Server Launching Examples
#
# ### Ensure the notebooks run on the .vevn kernel with the requirements.txt installed
#
# ### See [gpt_model_loader](./notebooks/gpt_model_loader.ipynb) for more information about the design and purpose of the load function.

# %%
## ensure the notebooks run the vevn with the requirements.txt installed
## specify relative paths to files test and train
# !python ./server.py --classifier_type 'few-shot' --train_ds_path './data/atis/train.tsv' --test_ds_path './data/atis/test.tsv'


# output contains model information (arguments)
# actual vs predicted intents for the evaluation dataset
# evaluation metrics 
# loading status
# Out:
# [nltk_data] Downloading package stopwords to /Users/lefos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
# class (classifier):  GPT
# model_name:  gpt-3.5-turbo
# model_classifier_type:  few-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
#
#
# model_unknown_targets:  {'day_name'}
#
# test size:  50
# unique eval classes:  19
# eval samples per class:  2
# any remaining test records will be sampled randomly
#
# valid,  invalid
# 50 0
# ['flight'] ['flight', 'ground_fare', 'distance']
# ['flight'] ['flight', 'quantity', 'flight_time']
# ['airfare'] ['flight', 'flight_no', 'airfare']
# ['airfare'] ['cheapest', 'airfare', 'airline']
# ['flight', 'airfare'] ['flight', 'airfare', 'abbreviation']
# ['flight', 'airfare'] ['flight', 'airfare', 'quantity']
# ['ground_service'] ['ground_service', 'airport', 'city']
# ['ground_service'] ['ground_service', 'airport', 'city']
# ['meal'] ['meal', 'airport', 'flight_no']
# ...

# %%
# !python ./server.py --classifier_type 'zero-shot' --train_ds_path './data/atis/train.tsv' --test_ds_path './data/atis/test.tsv'

# output contains model information (arguments)
# actual vs predicted intents for the evaluation dataset
# evaluation metrics 
# loading status
# Out:
# [nltk_data] Downloading package stopwords to /Users/lefos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#
# class (classifier):  GPT
# model_name:  gpt-3.5-turbo
# model_classifier_type:  zero-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
#
#
# model_unknown_targets:  {'day_name'}
#
# test size:  50
# unique eval classes:  19
# eval samples per class:  2
# any remaining test records will be sampled randomly
#
# valid,  invalid
# 50 0
# ['flight'] ['flight', 'flight_no', 'airport']
# ['flight'] ['flight', 'city', 'flight_no']
# ['airfare'] ['airfare', 'airport', 'city']
# ['airfare'] ['airfare', 'city', 'flight_time']
# ['flight', 'airfare'] ['airfare', 'flight', 'city']
# ['flight', 'airfare'] ['airfare', 'flight', 'city']
# ['ground_service'] ['ground_service', 'airport', 'city']
# ['ground_service'] ['airport', 'ground_service', 'city']
# ['meal'] ['meal', 'airport', 'airline']
# ...

# %% [markdown]
# ## Test Response Validator
#
# ### Run experiments
#
# Set bad responses by hand and try to load the model
#
# ### Important: **ONLY FOR DEMONSTRATION PURPOSES** -> Cause program to stop when receiving a bad response.
#
# ### Under non-Test conditions the loading will continue and the model load status will be loaded based on a range of
# ### [evaluation_metrics](./notebooks/evaluation_metrics.ipynb).

# %% [markdown]
# #### Set response to [3,   99, 5]: should be flagged as malformed since 99 is not a valid label

# %%
## ensure the notebooks run the vevn with the requirements.txt installed
## specify relative paths to files test and train
# !python ./server.py --classifier_type 'few-shot' --train_ds_path './data/atis/train.tsv' --test_ds_path './data/atis/test.tsv'
# Out:
# [nltk_data] Downloading package stopwords to /Users/lefos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# model_name:  gpt-3.5-turbo
# model_classifier_type:  few-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
# model_unknown_targets:  {'day_name'}
#
# test size:  1
# unique eval classes:  19
# eval samples per class:  0
# bad response:  [3, 99, 5]
# Test Success. Identified Bad response correctly. The server will now Stop
#
# valid,  invalid
# 0 1
# Traceback (most recent call last):
#   File "/Users/lefos/Desktop/intent_classifier_service/./server.py", line 178, in <module>
#     main()
#   File "/Users/lefos/Desktop/intent_classifier_service/./server.py", line 175, in main
#     raise HTTPException(status_code=500, detail="Model did not Load Successfully")
# fastapi.exceptions.HTTPException: 500: Model did not Load Successfully

# %% [markdown]
# #### Set response to '                         [3,        1, 5      ]': spaces are handled successfully, given that the list contains only valid labels represented by 3 integers

# %%
## ensure the notebooks run the vevn with the requirements.txt installed
## specify relative paths to files test and train
# !python ./server.py --classifier_type 'few-shot' --train_ds_path './data/atis/train.tsv' --test_ds_path './data/atis/test.tsv'
# Out:
# [nltk_data] Downloading package stopwords to /Users/lefos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# model_name:  gpt-3.5-turbo
# model_classifier_type:  few-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
# model_unknown_targets:  {'day_name'}
#
# test size:  1
# unique eval classes:  19
# eval samples per class:  0
#
# valid,  invalid
# 1 0
# ['ground_service'] ['aircraft', 'flight_time', 'airport']
#
# :      accuracy
# 0       0.0
#
# :               intent  precision
# 0           flight        0.0
# 1      flight_time        0.0
# 2          airfare        0.0
# 3         aircraft        0.0
# 4   ground_service        0.0
# 5          airport        0.0
# 6          airline        0.0
# 7         distance        0.0
# 8     abbreviation        0.0
# 9      ground_fare        0.0
# 10        quantity        0.0
# 11            city        0.0
# 12       flight_no        0.0
# ...

# %% [markdown]
# #### Set response to '[3, 1, ]': malformed since list has only 2 integers sep by commas

# %%
# !python ./server.py --classifier_type 'zero-shot' --train_ds_path './data/atis/train.tsv' --test_ds_path './data/atis/test.tsv'
# Out:
# [nltk_data] Downloading package stopwords to /Users/lefos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# model_name:  gpt-3.5-turbo
# model_classifier_type:  zero-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
# model_unknown_targets:  {'day_name'}
#
# test size:  1
# unique eval classes:  19
# eval samples per class:  0
# bad response:      [3, 1, ]
# Test Success. Identified Bad response correctly. The server will now Stop
#
# valid,  invalid
# 0 1
# Traceback (most recent call last):
#   File "/Users/lefos/Desktop/intent_classifier_service/./server.py", line 178, in <module>
#     main()
#   File "/Users/lefos/Desktop/intent_classifier_service/./server.py", line 175, in main
#     raise HTTPException(status_code=500, detail="Model did not Load Successfully")
# fastapi.exceptions.HTTPException: 500: Model did not Load Successfully

# %% [markdown]
# #### Set response to '3, 1, 2': malformed since string is not representing a list

# %%
# !python ./server.py --classifier_type 'zero-shot' --train_ds_path './data/atis/train.tsv' --test_ds_path './data/atis/test.tsv'
# Out:
# [nltk_data] Downloading package stopwords to /Users/lefos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# model_name:  gpt-3.5-turbo
# model_classifier_type:  zero-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
# model_unknown_targets:  {'day_name'}
#
# test size:  1
# unique eval classes:  19
# eval samples per class:  0
# bad response:  3, 1, 2
# Test Success. Identified Bad response correctly. The server will now Stop
#
# valid,  invalid
# 0 1
# Traceback (most recent call last):
#   File "/Users/lefos/Desktop/intent_classifier_service/./server.py", line 178, in <module>
#     main()
#   File "/Users/lefos/Desktop/intent_classifier_service/./server.py", line 175, in main
#     raise HTTPException(status_code=500, detail="Model did not Load Successfully")
# fastapi.exceptions.HTTPException: 500: Model did not Load Successfully

# %% [markdown]
# #### Set response to '[@, 3, 2 1]': malformed since string is not representing a list of 3 integers

# %%
# !python ./server.py --classifier_type 'zero-shot' --train_ds_path './data/atis/train.tsv' --test_ds_path './data/atis/test.tsv'
# Out:
# [nltk_data] Downloading package stopwords to /Users/lefos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# model_name:  gpt-3.5-turbo
# model_classifier_type:  zero-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
# model_unknown_targets:  {'day_name'}
#
# test size:  1
# unique eval classes:  19
# eval samples per class:  0
# bad response:  [@, 3, 2 1]
# Test Success. Identified Bad response correctly. The server will now Stop
#
# valid,  invalid
# 0 1
# Traceback (most recent call last):
#   File "/Users/lefos/Desktop/intent_classifier_service/./server.py", line 178, in <module>
#     main()
#   File "/Users/lefos/Desktop/intent_classifier_service/./server.py", line 175, in main
#     raise HTTPException(status_code=500, detail="Model did not Load Successfully")
# fastapi.exceptions.HTTPException: 500: Model did not Load Successfully

# %% [markdown]
# #### Set response to "['flight', 'airfare', 'city']": malformed since string is not representing a list of 3 integers

# %%
# !python ./server.py --classifier_type 'zero-shot' --train_ds_path './data/atis/train.tsv' --test_ds_path './data/atis/test.tsv'
# Out:
# [nltk_data] Downloading package stopwords to /Users/lefos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# model_name:  gpt-3.5-turbo
# model_classifier_type:  zero-shot
# model_train_ds_path:  ./data/atis/train.tsv
# model.test_ds_path:  ./data/atis/test.tsv
# model_unknown_targets:  {'day_name'}
#
# test size:  1
# unique eval classes:  19
# eval samples per class:  0
# bad response:  ['flight', 'airfare', 'city']
# Test Success. Identified Bad response correctly. The server will now Stop
#
# valid,  invalid
# 0 1
# Traceback (most recent call last):
#   File "/Users/lefos/Desktop/intent_classifier_service/./server.py", line 178, in <module>
#     main()
#   File "/Users/lefos/Desktop/intent_classifier_service/./server.py", line 175, in main
#     raise HTTPException(status_code=500, detail="Model did not Load Successfully")
# fastapi.exceptions.HTTPException: 500: Model did not Load Successfully
